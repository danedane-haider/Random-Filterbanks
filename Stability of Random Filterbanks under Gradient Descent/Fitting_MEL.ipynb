# %%
import numpy as np
import torch
# %matplotlib inline
from matplotlib import pyplot as plt
import tqdm
import torch.nn.functional as F
import torch.nn as nn
import pickle
import fb_utils as fb
from torch.utils.data import DataLoader
import random
import os

from model import TDFilterbank
from dataset import NTVOW
from losses import KappaLoss

# %%
# set seed
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
random.seed(0)
np.random.seed(0)

# %%
config = {
        "N": 4095,
        "J": 42,
        "T": 1024,
        "sr": 16000,
        "fmin": 64,
        "fmax": 8000,
        "stride": 585,
        "batch_size": 64,
        "epochs": 100,
    }

config = {
        "N": 4092,
        "J": 58,
        "T": 1024,
        "sr": 16000,
        "fmin": 64,
        "fmax": 8000,
        "stride": 341,
        "batch_size": 64,
        "epochs": 100,
        "epoch_size": 50,
    }

#data_dir="/Users/felixperfler/Documents/ISF/Random-Filterbanks/NTVOW"
data_dir="/Users/Dane/Documents/GitHub/Random-Filterbanks/NTVOW"

random_filterbank = fb.random_filterbank(config["N"], config["J"], config["T"], tight=False, support_only=False, to_torch=False)
random_filterbank = fb.fir_tightener3000(random_filterbank, config["T"], eps=1.01)
random_filterbank = random_filterbank[:, :config["T"]]
random_filterbank = torch.from_numpy(random_filterbank)
target = 'CQT'
# get current working directory of file
cwd = os.path.abspath('')

with open(cwd+'/targets/'+target+'.pkl', 'rb') as fp:
    target_filterbank = pickle.load(fp)["freqz"]
    target_filterbank = torch.from_numpy(target_filterbank.T)

# device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
device = 'cpu'

# %%
model_baseline = TDFilterbank(config, random_filterbank)
model_baseline.to(device)
model_kappa = TDFilterbank(config, random_filterbank)
model_kappa.to(device)
# Out:
# TDFilterbank(
#   (psi): Conv1d(1, 58, kernel_size=(1024,), stride=(341,), bias=False)
# )

# %%
train_dataset = NTVOW(data_dir, 'train', config, target_filterbank)
train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)

val_dataset = NTVOW(data_dir, 'val', config, target_filterbank)
val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=True)

# %%
loss_baseline = KappaLoss(beta=0)
loss_kappa = KappaLoss(beta=1e-2)

# %%
optimizer_baseline = torch.optim.Adam(model_baseline.parameters(), lr=1e-5)
optimizer_kappa = torch.optim.Adam(model_kappa.parameters(), lr=1e-5)

# %%
fit_baseline = []
fit_val_baseline = []
fit_kappa = []
fit_val_kappa = []
kappa_baseline = []
kappa_val_baseline = []
kappa_kappa = []
kappa_val_kappa = []

w = model_baseline.psi.weight.detach().numpy()[:,0,:]
w = np.pad(w, ((0,0),(0, config["N"]-config["T"])), constant_values=0)
A,B = fb.frame_bounds_lp(w)
kappa_baseline.append(B/A)
kappa_val_baseline.append(B/A)

w = model_kappa.psi.weight.detach().numpy()[:,0,:]
w = np.pad(w, ((0,0),(0, config["N"]-config["T"])), constant_values=0)
A,B = fb.frame_bounds_lp(w)
kappa_kappa.append(B/A)
kappa_val_kappa.append(B/A)

print(f"Init condition numbers:")
print(f"\tBaseline condition number {kappa_baseline[-1]:.2f}")
print(f"\tKappa condition number {kappa_kappa[-1]:.2f}")

for epoch in range(config["epochs"]):
    running_loss = 0.0
    running_kappa = 0.0

    running_val_loss = 0.0
    running_val_kappa = 0.0

    model_baseline.train()
    model_kappa.train()

    for batch in train_loader:
        x = batch['x'].to(device)
        x_out = batch['x_out'].to(device)
        
        x_out_baseline = model_baseline(x)
        base_loss_i, _ = loss_baseline(x_out_baseline, x_out)
        
        x_out_kappa = model_kappa(x)
        w = model_kappa.psi.weight[:,0,:]
        w = F.pad(w,(0,config["N"]-config["T"]), value=0)
        base_loss_kappa_i, loss_kappa_i = loss_kappa(x_out_kappa, x_out, w)

        optimizer_baseline.zero_grad()
        base_loss_i.backward()
        optimizer_baseline.step()

        optimizer_kappa.zero_grad()
        loss_kappa_i.backward()
        optimizer_kappa.step()

        running_loss += base_loss_i.item()
        running_kappa += base_loss_kappa_i.item()
    
    model_baseline.eval()
    model_kappa.eval()
    with torch.no_grad():
        for batch in val_loader:
            x = batch['x'].to(device)
            x_out = batch['x_out'].to(device)
            
            x_out_baseline = model_baseline(x)
            base_loss_i, _ = loss_baseline(x_out_baseline, x_out)
            
            x_out_kappa = model_kappa(x)
            w = model_kappa.psi.weight[:,0,:]
            w = F.pad(w,(0,config["N"]-config["T"]), value=0)
            base_loss_kappa_i, loss_kappa_i = loss_kappa(x_out_kappa, x_out, w)

            running_val_loss += base_loss_i.item()
            running_val_kappa += base_loss_kappa_i.item()

    w = model_baseline.psi.weight.detach().numpy()[:,0,:]
    w = np.pad(w, ((0,0),(0, config["N"]-config["T"])), constant_values=0)
    A,B = fb.frame_bounds_lp(w)
    kappa_baseline.append(B/A)
    
    w = model_kappa.psi.weight.detach().numpy()[:,0,:]
    w = np.pad(w, ((0,0),(0, config["N"]-config["T"])), constant_values=0)
    A,B = fb.frame_bounds_lp(w)
    kappa_kappa.append(B/A)

    fit_baseline.append(running_loss/len(train_loader))
    fit_kappa.append(running_kappa/len(train_loader))

    w = model_baseline.psi.weight.detach().numpy()[:,0,:]
    w = np.pad(w, ((0,0),(0, config["N"]-config["T"])), constant_values=0)
    A,B = fb.frame_bounds_lp(w)
    kappa_val_baseline.append(B/A)
    
    w = model_kappa.psi.weight.detach().numpy()[:,0,:]
    w = np.pad(w, ((0,0),(0, config["N"]-config["T"])), constant_values=0)
    A,B = fb.frame_bounds_lp(w)
    kappa_val_kappa.append(B/A)

    fit_val_baseline.append(running_val_loss/len(val_loader))
    fit_val_kappa.append(running_val_kappa/len(val_loader))


    print(f"Epoch {epoch+1}/{config['epochs']}:")
    print(f"\tBaseline Loss: {fit_baseline[-1]:.2f} with condition number {kappa_baseline[-1]:.2f}")
    print(f"\tKappa Loss: {fit_kappa[-1]:.2f} with condition number {kappa_kappa[-1]:.2f}")

    # if fit_kappa[-1] - fit_baseline[-1] > 1e-25:
    #     loss_kappa.beta = loss_kappa.beta/2
    #     print(f"\tDecreasing kappa loss weight to {loss_kappa.beta:.2e}")
    # elif fit_kappa[-1] - fit_baseline[-1] < -1e-25:
    #     loss_kappa.beta = loss_kappa.beta*2
    #     print(f"\tIncreasing kappa loss weight to {loss_kappa.beta:.2e}")
# Out:
# Init condition numbers:
# 	Baseline condition number 1.01
# 	Kappa condition number 1.01
# Epoch 1/100:
# 	Baseline Loss: 0.13 with condition number 1.70
# 	Kappa Loss: 0.13 with condition number 1.03
# Epoch 2/100:
# 	Baseline Loss: 0.11 with condition number 2.48
# 	Kappa Loss: 0.11 with condition number 1.03
# Epoch 3/100:
# 	Baseline Loss: 0.10 with condition number 3.37
# 	Kappa Loss: 0.10 with condition number 1.03
# Epoch 4/100:
# 	Baseline Loss: 0.09 with condition number 4.40
# 	Kappa Loss: 0.09 with condition number 1.04
# Epoch 5/100:
# 	Baseline Loss: 0.08 with condition number 5.68
# 	Kappa Loss: 0.09 with condition number 1.04
# Epoch 6/100:
# 	Baseline Loss: 0.08 with condition number 6.82
# 	Kappa Loss: 0.09 with condition number 1.04
# Epoch 7/100:
# 	Baseline Loss: 0.08 with condition number 8.12
# 	Kappa Loss: 0.08 with condition number 1.04
# Epoch 8/100:
# 	Baseline Loss: 0.08 with condition number 9.38
# 	Kappa Loss: 0.08 with condition number 1.04
# Epoch 9/100:
# 	Baseline Loss: 0.07 with condition number 10.72
# 	Kappa Loss: 0.08 with condition number 1.04
# Epoch 10/100:
# 	Baseline Loss: 0.07 with condition number 11.92
# 	Kappa Loss: 0.08 with condition number 1.04
# Epoch 11/100:
# 	Baseline Loss: 0.07 with condition number 13.44
# 	Kappa Loss: 0.07 with condition number 1.04
# Epoch 12/100:
# 	Baseline Loss: 0.07 with condition number 14.56
# 	Kappa Loss: 0.07 with condition number 1.04
# Epoch 13/100:
# 	Baseline Loss: 0.07 with condition number 15.86
# 	Kappa Loss: 0.07 with condition number 1.04
# Epoch 14/100:
# 	Baseline Loss: 0.06 with condition number 16.52
# 	Kappa Loss: 0.07 with condition number 1.04
# Epoch 15/100:
# 	Baseline Loss: 0.06 with condition number 17.53
# 	Kappa Loss: 0.07 with condition number 1.04
# Epoch 16/100:
# 	Baseline Loss: 0.06 with condition number 19.02
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 17/100:
# 	Baseline Loss: 0.06 with condition number 19.66
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 18/100:
# 	Baseline Loss: 0.06 with condition number 20.67
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 19/100:
# 	Baseline Loss: 0.06 with condition number 21.53
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 20/100:
# 	Baseline Loss: 0.06 with condition number 22.60
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 21/100:
# 	Baseline Loss: 0.06 with condition number 23.19
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 22/100:
# 	Baseline Loss: 0.05 with condition number 23.35
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 23/100:
# 	Baseline Loss: 0.05 with condition number 24.14
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 24/100:
# 	Baseline Loss: 0.05 with condition number 24.82
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 25/100:
# 	Baseline Loss: 0.05 with condition number 25.33
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 26/100:
# 	Baseline Loss: 0.05 with condition number 25.63
# 	Kappa Loss: 0.06 with condition number 1.04
# Epoch 27/100:
# 	Baseline Loss: 0.05 with condition number 26.45
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 28/100:
# 	Baseline Loss: 0.05 with condition number 26.72
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 29/100:
# 	Baseline Loss: 0.05 with condition number 26.53
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 30/100:
# 	Baseline Loss: 0.05 with condition number 28.15
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 31/100:
# 	Baseline Loss: 0.05 with condition number 27.15
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 32/100:
# 	Baseline Loss: 0.05 with condition number 28.58
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 33/100:
# 	Baseline Loss: 0.05 with condition number 27.20
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 34/100:
# 	Baseline Loss: 0.05 with condition number 27.95
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 35/100:
# 	Baseline Loss: 0.05 with condition number 28.51
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 36/100:
# 	Baseline Loss: 0.05 with condition number 28.02
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 37/100:
# 	Baseline Loss: 0.05 with condition number 27.73
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 38/100:
# 	Baseline Loss: 0.05 with condition number 27.66
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 39/100:
# 	Baseline Loss: 0.05 with condition number 28.23
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 40/100:
# 	Baseline Loss: 0.05 with condition number 28.59
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 41/100:
# 	Baseline Loss: 0.05 with condition number 29.29
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 42/100:
# 	Baseline Loss: 0.04 with condition number 28.81
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 43/100:
# 	Baseline Loss: 0.04 with condition number 28.64
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 44/100:
# 	Baseline Loss: 0.04 with condition number 28.77
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 45/100:
# 	Baseline Loss: 0.04 with condition number 28.71
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 46/100:
# 	Baseline Loss: 0.04 with condition number 28.70
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 47/100:
# 	Baseline Loss: 0.04 with condition number 29.50
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 48/100:
# 	Baseline Loss: 0.04 with condition number 29.60
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 49/100:
# 	Baseline Loss: 0.04 with condition number 29.76
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 50/100:
# 	Baseline Loss: 0.04 with condition number 30.13
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 51/100:
# 	Baseline Loss: 0.04 with condition number 29.84
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 52/100:
# 	Baseline Loss: 0.04 with condition number 29.90
# 	Kappa Loss: 0.05 with condition number 1.04
# Epoch 53/100:
# 	Baseline Loss: 0.04 with condition number 30.83
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 54/100:
# 	Baseline Loss: 0.04 with condition number 30.59
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 55/100:
# 	Baseline Loss: 0.04 with condition number 30.40
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 56/100:
# 	Baseline Loss: 0.04 with condition number 30.48
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 57/100:
# 	Baseline Loss: 0.04 with condition number 31.87
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 58/100:
# 	Baseline Loss: 0.04 with condition number 31.99
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 59/100:
# 	Baseline Loss: 0.04 with condition number 31.13
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 60/100:
# 	Baseline Loss: 0.04 with condition number 31.53
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 61/100:
# 	Baseline Loss: 0.04 with condition number 31.74
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 62/100:
# 	Baseline Loss: 0.04 with condition number 31.45
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 63/100:
# 	Baseline Loss: 0.04 with condition number 31.24
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 64/100:
# 	Baseline Loss: 0.04 with condition number 31.87
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 65/100:
# 	Baseline Loss: 0.04 with condition number 31.98
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 66/100:
# 	Baseline Loss: 0.04 with condition number 30.80
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 67/100:
# 	Baseline Loss: 0.04 with condition number 30.65
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 68/100:
# 	Baseline Loss: 0.04 with condition number 31.63
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 69/100:
# 	Baseline Loss: 0.04 with condition number 32.34
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 70/100:
# 	Baseline Loss: 0.04 with condition number 32.15
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 71/100:
# 	Baseline Loss: 0.04 with condition number 33.37
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 72/100:
# 	Baseline Loss: 0.04 with condition number 32.76
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 73/100:
# 	Baseline Loss: 0.04 with condition number 32.68
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 74/100:
# 	Baseline Loss: 0.04 with condition number 33.48
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 75/100:
# 	Baseline Loss: 0.04 with condition number 34.21
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 76/100:
# 	Baseline Loss: 0.04 with condition number 33.58
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 77/100:
# 	Baseline Loss: 0.04 with condition number 34.38
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 78/100:
# 	Baseline Loss: 0.04 with condition number 34.23
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 79/100:
# 	Baseline Loss: 0.04 with condition number 34.44
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 80/100:
# 	Baseline Loss: 0.04 with condition number 34.48
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 81/100:
# 	Baseline Loss: 0.04 with condition number 35.03
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 82/100:
# 	Baseline Loss: 0.03 with condition number 35.34
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 83/100:
# 	Baseline Loss: 0.03 with condition number 36.04
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 84/100:
# 	Baseline Loss: 0.03 with condition number 36.74
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 85/100:
# 	Baseline Loss: 0.03 with condition number 37.31
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 86/100:
# 	Baseline Loss: 0.03 with condition number 37.53
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 87/100:
# 	Baseline Loss: 0.03 with condition number 37.64
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 88/100:
# 	Baseline Loss: 0.03 with condition number 38.84
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 89/100:
# 	Baseline Loss: 0.03 with condition number 38.61
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 90/100:
# 	Baseline Loss: 0.03 with condition number 38.10
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 91/100:
# 	Baseline Loss: 0.03 with condition number 37.40
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 92/100:
# 	Baseline Loss: 0.03 with condition number 37.03
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 93/100:
# 	Baseline Loss: 0.03 with condition number 37.72
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 94/100:
# 	Baseline Loss: 0.03 with condition number 38.56
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 95/100:
# 	Baseline Loss: 0.03 with condition number 39.35
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 96/100:
# 	Baseline Loss: 0.03 with condition number 39.72
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 97/100:
# 	Baseline Loss: 0.03 with condition number 39.52
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 98/100:
# 	Baseline Loss: 0.03 with condition number 40.19
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 99/100:
# 	Baseline Loss: 0.03 with condition number 39.69
# 	Kappa Loss: 0.04 with condition number 1.04
# Epoch 100/100:
# 	Baseline Loss: 0.03 with condition number 39.44
# 	Kappa Loss: 0.04 with condition number 1.04

# %%
# plot losses and condition numbers over epochs

plt.rcParams['text.usetex'] = False

fig, axes = plt.subplots(2, 1, figsize=(6, 4), sharex=True)
Ts = np.arange(0, config['epochs']+1)

ax = axes[0]
ax.plot(Ts[1:], fit_baseline, 'tab:blue', linewidth=2, label='$P(\Phi)=0$')
ax.plot(Ts[1:], fit_kappa, 'tab:green', linewidth=2, label='$P(\Phi)=\kappa$')
ax.plot(Ts[1:], fit_val_baseline, 'tab:orange', linewidth=2, linestyle='--', label='Val $P(\Phi)=0$')
ax.plot(Ts[1:], fit_val_kappa, 'tab:red', linewidth=2, linestyle='--', label='Val $P(\Phi)=\kappa$')

ax.set_yscale('log')
ax.set_title(target+' Losses')
ax.grid(linestyle='--', alpha=0.5)

ax = axes[1]
ax.plot(Ts, kappa_baseline, 'tab:blue', linewidth=2)
ax.plot(Ts, kappa_kappa, 'tab:green', linewidth=2)
ax.plot(Ts, np.ones(len(Ts)), 'tab:gray', linewidth=2, label='Tightened', linestyle='-.')
ax.set_yscale('log')

ax.set_title('Condition numbers')
ax.set_xlabel('Epochs')
axes[0].legend(loc='upper right')
ax.grid(linestyle='--', alpha=0.5)

plt.tight_layout()

plt.savefig('Fitting_CQT3.pdf', bbox_inches='tight')

# %%
256*40/2
# Out:
# 5120.0
